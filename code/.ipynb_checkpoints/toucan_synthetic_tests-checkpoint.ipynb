# %%
from tsvd import *
import numpy as np
import time
import matplotlib.pyplot as plt

from tecpsgd import *
from olstec import *

# %%
# r =  3
# n1 = 50
# n2 = 100
# n3 = 50

# r = 5
# n1 = 100
# n2 = 500
# n3 = 100

r = 3
# r = 5
n1 = 200
n2 = 500
# n3 = 25
n3 = 20

# r =  5
# n1 = 200
# n2 = 400
# n3 = 200

np.random.seed(0)
# P = tsvd(Tensor(np.random.randn(n1,r,n3)),full=False)[0]
P = Tensor(np.random.randn(n1,n1,n3))
Utrue = Tensor(P.array()[:,:r,:])

W = Tensor(np.random.randn(r, n2, n3))
L = Utrue * W

tube = False
rho = 0.75  # percentage of missing entries
# rho = 0.85
# rho = 1 - r*n3 / (n1*n3)
print(rho)

if(tube is False):
    mask = np.random.rand(n1, n2, n3)
    mask[mask > rho] = 1
    mask[mask <= rho] = 0
    mask = mask.astype(int)
else:
    mask = np.random.rand(n1, n2)
    mask[mask > rho] = 1
    mask[mask <= rho] = 0
    mask = mask.astype(int)
    mask = np.repeat(mask[:, :, np.newaxis], n3, axis=2)
    
sig = 0

L += Tensor(sig*np.random.randn(n1,n2,n3))

Lfrob = tfrobnorm(L)

tol = 1e-9

Ut,St,Vt = tsvd(L,full=False)
sing_vals = np.diag(St.array()[:,:,0])
plt.figure(figsize=(13,5),tight_layout=True)
plt.plot(np.arange(0,min(n1,n2)),sing_vals)
plt.xticks(np.arange(0, min(n1,n2), step=5))
plt.xlabel('Index')
plt.title('Tensor tubal values')
plt.show()

condition_num = sing_vals[0] / sing_vals[r-1]

print('Condition number: {:5f}'.format(condition_num))

# print(np.diag(St.array()[:,:,0]))

# for i in range(0,n3):
#     U,S,V = np.linalg.svd(L.array()[:,:,i],full_matrices=False)
#     plt.plot(S)
# plt.title('Frontal Slice Singular Values')
# plt.xlabel('Index')
# plt.show()

# for i in range(0,n1):
#     U,S,V = np.linalg.svd(L.array()[i,:,:],full_matrices=False)
#     plt.plot(S)
# plt.title('Horizontal Slice Singular Values')
# plt.xlabel('Index')
# plt.show()

# for i in range(0,n2):
#     U,S,V = np.linalg.svd(L.array()[:,i,:],full_matrices=False)
#     plt.plot(S)
# plt.title('Lateral Slice Singular Values')
# plt.xlabel('Index')
# plt.show()
# Out:
# 0.75
# Condition number: 1.398061

# %%
# # r =  5
# # n1 = 100
# # n2 = 200
# # n3 = 100
# np.random.seed(0)

# A=np.linalg.svd(np.random.randn(n1, r),full_matrices=False)[0]
# B=np.linalg.svd(np.random.randn(n2, r),full_matrices=False)[0]
# C=np.linalg.svd(np.random.randn(n3, r),full_matrices=False)[0]

# # A=np.random.randn(n1, r) 
# # B=np.random.randn(n2, r)
# # B = B / np.linalg.norm(B,axis=0)
# # C=np.random.randn(n3, r)

# #Create observed tensor that follows PARAFAC model
# Tensor_Y_Noiseless = np.zeros((n1,n2,n3))
# for k in range(0,n3):
#     Tensor_Y_Noiseless[:,:,k]=A@np.diag(C[k,:])@B.T

# # L = Tensor(np.transpose(Tensor_Y_Noiseless,[0,2,1]))
# L = Tensor(Tensor_Y_Noiseless)
# Lfrob = tfrobnorm(L)
# print(L.shape())

# tube = True
# rho = 0.5  # percentage of missing entries

# if(tube is False):
#     mask = np.random.rand(n1, n2, n3)
#     mask[mask > rho] = 1
#     mask[mask <= rho] = 0
#     mask = mask.astype(int)
# else:
#     mask = np.random.rand(n1, n2)
#     mask[mask > rho] = 1
#     mask[mask <= rho] = 0
#     mask = mask.astype(int)
#     mask = np.repeat(mask[:, :, np.newaxis], n3, axis=2)
    
# # mask = np.transpose(mask,[0,2,1])

# # Y_m = np.reshape(Tensor_Y_Noiseless,(n1*n3,n2))
# # U,S,V = np.linalg.svd(Y_m,full_matrices=False)
# # plt.plot(S)
# # plt.xticks(np.arange(0, min(n1,n1), step=10))
# # plt.show()

# U,S,V = tsvd(L,full=False)
# sing_vals = np.diag(S.array()[:,:,0])
# plt.figure(figsize=(13,5),tight_layout=True)
# plt.plot(np.arange(0,min(n1,n2)),sing_vals)
# plt.xticks(np.arange(0, min(n1,n2), step=5))
# plt.title('Tubal singular values')
# # plt.yticks(np.arange(0,np.max(S.array()),step=500))
# plt.show()

# condition_num = sing_vals[0] / sing_vals[r-1]
# print('Condition number: {:5f}'.format(condition_num))

# %%
Y = Tensor(L.array() * mask)
# Tensor_Y_Noiseless = np.transpose(L.array() * mask,[0,2,1])
# # Tensor_Y_Noiseless = L.array().copy()
# rank = 100
# OmegaTensor = np.transpose(mask,[0,2,1])
# # OmegaTensor = mask.copy()

# tensor_dims = [n1,n3,n2]
# # tensor_dims = [n1,n2,n3]

# %%
# rank = 5
# Xinit = {
#     'A': np.random.randn(tensor_dims[0], rank),
#     'B': np.random.randn(tensor_dims[1], rank),
#     'C': np.random.randn(tensor_dims[2], rank)
# }

# %%
# ## TeCPSGD

# maxepochs = 5
# tolcost = 1e-14
# permute_on = False

# options = {
#     'maxepochs': maxepochs,
#     'tolcost': tolcost,
#     'lam': 0.001,
#     'stepsize': 1,
#     'permute_on':  permute_on,
#     'store_subinfo': True,
#     'store_matrix': False,
#     'verbose': True
# }


# Xsol_TeCPSGD, Y_hat_tecpsgd, info_TeCPSGD, sub_infos_TeCPSGD = TeCPSGD(Tensor_Y_Noiseless, OmegaTensor, None, tensor_dims, rank,
#                                                           Xinit, options)

# A_t0 = Xsol_TeCPSGD['A']
# B_t0 = Xsol_TeCPSGD['B']
# C_t0 = Xsol_TeCPSGD['C']

# nrmse_tecpsgd = frobnorm(Y_hat_tecpsgd - Tensor_Y_Noiseless) / frobnorm(Tensor_Y_Noiseless)
# print(nrmse_tecpsgd)

# %%
# ## OLSTEC

# # Tensor_Y_Noiseless = np.transpose(L.array(),[0,2,1])
# Tensor_Y_Noiseless = L.array()
# rank = 20
# # OmegaTensor = np.transpose(mask,[0,2,1])
# OmegaTensor = mask
# # tensor_dims = [n1,n3,n2]
# tensor_dims = [n1,n2,n3]
# maxepochs = 1
# tolcost = 1e-14
# permute_on = False

# options = {
#     'maxepochs': maxepochs,
#     'tolcost': tolcost,
#     'lam': 1,
#     'mu': 0.01,
#     'permute_on':  permute_on,
#     'store_subinfo': True,
#     'store_matrix': False,
#     'verbose': True,
#     'tw_flag': None,
#     'tw_len': None
# }

# np.random.seed(0)
# Xinit = {
#     'A': np.random.randn(tensor_dims[0], rank),
#     'B': np.random.randn(tensor_dims[1], rank),
#     'C': np.random.randn(tensor_dims[2], rank)
# }

# print(Tensor_Y_Noiseless.shape)
# Xsol_olstec, Y_hat_olstec, info_olstec, sub_infos_olstec = OLSTEC(Tensor_Y_Noiseless, OmegaTensor, None, tensor_dims, rank,
#                                                           Xinit, options)

# A_t0 = Xsol_olstec['A']
# B_t0 = Xsol_olstec['B']
# C_t0 = Xsol_olstec['C']

# %%
## TNN-ADMM

fun = lambda X: [0, tfrobnorm(X - L) / Lfrob]

niter = 200

Xhat, stats, tElapsed_tensor = lrtc(Y, mask, niter=niter,tol=tol, fun=fun)

cost_tensor = stats[:,0]
nrmse_tensor = stats[:,1]
times_tensor = stats[:,2]

print('Time elapsed: Tensor: {:.3f} '.format(tElapsed_tensor))
print('Final NRMSE: Tensor: {:.8f} '.format(nrmse_tensor[-1]))

plt.subplot(1,2,1)
plt.semilogy(cost_tensor)
plt.xlabel('Iteration')
plt.title('Cost function')
plt.subplot(1,2,2)
plt.semilogy(nrmse_tensor)
plt.xlabel('Iteration')
plt.title('NRMSE')
plt.show()
# Out:
# Time elapsed: Tensor: 146.432
# Final NRMSE: Tensor: 0.00000001

# %%
## TCTF

fun = lambda U,V: [0, tfrobnorm(U*V - L) / Lfrob]
Xtctf,Ztctf, stats_tctf, tElapsed_tctf = tctf(Y,mask,rank=r,niter = 250,tol=tol,fun=fun,verbose=True)
Y_hat_tctf = Xtctf * Ztctf

nrmse_tctf = stats_tctf[:,1]
times_tctf = stats_tctf[:,-1]
print('TCTF Time: {:4f}'.format(tElapsed_tctf))
print('TCTF NRMSE: {:8f}'.format(nrmse_tctf[-1]))

plt.semilogy(nrmse_tctf)
plt.xlabel('Iteration')
plt.title('NRMSE')
plt.show()
# Out:
# Iter[1]: NRMSE: 0.598989
# Iter[11]: NRMSE: 0.127463
# Iter[21]: NRMSE: 0.041223
# Iter[31]: NRMSE: 0.015048
# Iter[41]: NRMSE: 0.005834
# Iter[51]: NRMSE: 0.002344
# Iter[61]: NRMSE: 0.000965
# Iter[71]: NRMSE: 0.000404
# Iter[81]: NRMSE: 0.000172
# Iter[91]: NRMSE: 0.000074
# Iter[101]: NRMSE: 0.000032
# Iter[111]: NRMSE: 0.000014
# Iter[121]: NRMSE: 0.000006
# Iter[131]: NRMSE: 0.000003
# Iter[141]: NRMSE: 0.000001
# Iter[151]: NRMSE: 0.000001
# Iter[161]: NRMSE: 0.000000
# Iter[171]: NRMSE: 0.000000
# Iter[181]: NRMSE: 0.000000
# Iter[191]: NRMSE: 0.000000
# Iter[201]: NRMSE: 0.000000
# Iter[211]: NRMSE: 0.000000
# Iter[221]: NRMSE: 0.000000
# TCTF Time: 107.254856
# TCTF NRMSE: 0.000000

# %%
# ## Matrix Completion

# L_m = lr_flatten(L.array())
# mask_m = lr_flatten(mask)

# Y_m = L_m * mask_m

# start = time.time()
# U,S,V = np.linalg.svd(L_m,full_matrices=False)
# end = time.time()

# print(end - start)
# plt.figure(figsize=(13,5),tight_layout=True)

# plt.plot(np.arange(0,min(n1*n3,n2)),S)
# plt.xticks(np.arange(0, min(n1*n3,n2), step=25))
# plt.title('Singular values of matricized tensor')
# plt.xlabel('Index')
# plt.show()

# %%
# ## Matrix Completion

# cost_fun = lambda X: [0, np.linalg.norm(X - L_m, 'fro') / np.linalg.norm(L_m, 'fro')]

# niter_mc = 500
# Xhat_m, stats, tElapsed_matrix = lrmc(Y_m,mask_m,niter=niter_mc,fun=cost_fun)

# cost_matrix = stats[:,0]
# nrmse_matrix = stats[:,1]
# times_matrix = stats[:,2]

# print('Time elapsed: Mat Comp: {:.3f} '.format(tElapsed_matrix))
# print('Final NRMSE: Mat Comp: {:.8f} '.format(nrmse_matrix[-1]))

# %%
# ## GROUSE

# rank = r*n3
# # rank = r
# fun = lambda X: [0, np.linalg.norm(X - L_m, 'fro') / np.linalg.norm(L_m, 'fro')]
# Ym_hat_grouse, stats_grouse, tElapsed_grouse = grouse(Y_m, mask_m, rank,outer=5,mode="batch",fun=fun,randomOrder=False,
#                                                       verbose=False)
# grouse_nrmse = np.linalg.norm(Ym_hat_grouse - L_m,'fro') / np.linalg.norm(L_m,'fro')
# print('GROUSE Time: {:4f}'.format(tElapsed_grouse))
# print('GROUSE NRMSE: {:4f}'.format(grouse_nrmse))
        
# nrmse_grouse = stats_grouse[:,1]
# times_grouse = stats_grouse[:,-1]
# tElapsed_grouse = np.sum(times_grouse)
# plt.semilogy(nrmse_grouse)
# plt.title('GROUSE: Recovered Tensor NRMSE')
# plt.xlabel('Iteration')
# plt.show()

# %%
## TOUCAN
# Y = Tensor(L.array() * mask)

fun = lambda X,k: [0, tfrobnorm(X - L) / Lfrob]
# fun = lambda X,k: [0, tfrobnorm_array(X.array()[:,k,:] - L.array()[:,k,:]) / tfrobnorm_array(L.array()[:,k,:])]
Y_hat_toucan, U, stats_toucan, tElapsed_toucan = toucan(Y,mask,rank=r,tube=tube,outer=7,mode="batch",tol=tol,cgiter = None,cgtol=tol,fun=fun,
                                                     randomOrder=False,verbose=False)

toucan_nrmse = tfrobnorm(Y_hat_toucan - L) / Lfrob
print('TOUCAN Time: {:4f}'.format(tElapsed_toucan))
print('TOUCAN NRMSE: {:8f}'.format(toucan_nrmse))

nrmse_toucan = stats_toucan[:,1]
cgiter_toucan = stats_toucan[:,2]
times_toucan = stats_toucan[:,-1]
# Out:
# TOUCAN Time: 91.388837
# TOUCAN NRMSE: 0.000000

# %%
plt.semilogy(nrmse_toucan)
plt.title('TOUCAN: Recovered Tensor NRMSE')
plt.xlabel('Iteration')
plt.show()

plt.scatter(np.arange(0,len(cgiter_toucan[1:])),cgiter_toucan[1:])
plt.show()

# %%
plt.figure(figsize=(13,5),tight_layout=True)
plt.semilogy(np.cumsum(times_toucan), nrmse_toucan, '#ff7f0e', label='TOUCAN')
#              np.cumsum(times_grouse)[:int(0.5*len(times_grouse))], nrmse_grouse[:int(0.5*len(times_grouse))], 'b',
#              np.cumsum(times_grouse), nrmse_grouse, 'b',
#             np.cumsum(times_matrix), nrmse_matrix, 'g',label='MatComp',
plt.semilogy(np.cumsum(times_tensor), nrmse_tensor, 'r', label='TNN-ADMM')
plt.semilogy(np.cumsum(times_tctf), nrmse_tctf, 'k',label='TCTF')

# max_time = max(max(np.cumsum(times_matrix)),max(np.cumsum(times_tctf)),max(np.cumsum(times_grouse)),max(np.cumsum(times_tensor)),max(np.cumsum(times_toucan)))
max_time = max(max(np.cumsum(times_tctf)),max(np.cumsum(times_tensor)),max(np.cumsum(times_toucan)))
plt.xlabel('Time (s)')
plt.xticks(np.arange(0, max_time, step=20))
plt.legend(bbox_to_anchor=(1.5,0.5),loc='center right')
plt.rcParams.update({'font.size': 22})

if(tube is False):
    name = 'nrmse_times_rand_sample_' + str(r) + '-' + str(n1) + '-' + str(n2) + '-' + str(n3) + '-' + str(int(rho*100)) + '%.eps'
else:
    name = 'nrmse_times_tube_sample_' + str(r) + '-' + str(n1) + '-' + str(n2) + '-' + str(n3) + '-' + str(int(rho*100)) + '%.eps'
# plt.savefig(name)
plt.show()

# %%
# plt.semilogy(np.arange(0,len(nrmse_toucan)),nrmse_toucan, '#ff7f0e',
#              np.arange(0,len(nrmse_grouse)), nrmse_grouse, 'b',
#              np.arange(0,len(nrmse_tensor)), nrmse_tensor, 'r',
#              np.arange(0,len(nrmse_matrix)), nrmse_matrix, 'g')
# plt.xlabel('Iteration')
# plt.title('NRMSE')
# plt.legend(('TOUCAN','GROUSE','TNN','MatComp'))
# # plt.legend(('TOUCAN','TC'))
# plt.show()

# %%
tube = True
# rho = rho  # percentage of missing entries
# rho = 1 - r*n3 / (n1*n3)

if(tube is False):
    mask = np.random.rand(n1, n2, n3)
    mask[mask > rho] = 1
    mask[mask <= rho] = 0
    mask = mask.astype(int)
else:
    mask = np.random.rand(n1, n2)
    mask[mask > rho] = 1
    mask[mask <= rho] = 0
    mask = mask.astype(int)
    mask = np.repeat(mask[:, :, np.newaxis], n3, axis=2)
    
Y = Tensor(L.array() * mask)

# %%
## TNN-ADMM

fun = lambda X: [0, tfrobnorm(X - L) / Lfrob]

niter = 200

Xhat, stats, tElapsed_tensor = lrtc(Y, mask, niter=niter,tol=tol, fun=fun)

cost_tensor_tube = stats[:,0]
nrmse_tensor_tube = stats[:,1]
times_tensor_tube = stats[:,2]

print('Time elapsed: Tensor: {:.3f} '.format(tElapsed_tensor))
print('Final NRMSE: Tensor: {:.8f} '.format(nrmse_tensor_tube[-1]))

plt.subplot(1,2,1)
plt.semilogy(cost_tensor_tube)
plt.xlabel('Iteration')
plt.title('Cost function')
plt.subplot(1,2,2)
plt.semilogy(nrmse_tensor_tube)
plt.xlabel('Iteration')
plt.title('NRMSE')
plt.show()
# Out:
# Time elapsed: Tensor: 31.672
# Final NRMSE: Tensor: 0.00000000

# %%
## TCTF

fun = lambda U,V: [0, tfrobnorm(U*V - L) / Lfrob]
Xtctf,Ztctf, stats_tctf, tElapsed_tctf = tctf(Y,mask,rank=r,niter = 150,tol=tol,fun=fun,verbose=True)
Y_hat_tctf = Xtctf * Ztctf

nrmse_tctf_tube = stats_tctf[:,1]
times_tctf_tube = stats_tctf[:,-1]
print('TCTF Time: {:4f}'.format(tElapsed_tctf))
print('TCTF NRMSE: {:8f}'.format(nrmse_tctf_tube[-1]))

plt.semilogy(nrmse_tctf_tube)
plt.xlabel('Iteration')
plt.title('NRMSE')
plt.show()
# Out:
# Iter[1]: NRMSE: 0.270610
# Iter[11]: NRMSE: 0.001993
# Iter[21]: NRMSE: 0.000040
# Iter[31]: NRMSE: 0.000001
# Iter[41]: NRMSE: 0.000000
# Iter[51]: NRMSE: 0.000000
# TCTF Time: 11.210649
# TCTF NRMSE: 0.000000

# %%
## Matrix Completion

cost_fun = lambda X: [0, np.linalg.norm(X - L_m, 'fro') / np.linalg.norm(L_m, 'fro')]

niter_mc = 500
Xhat_m, stats, tElapsed_matrix = lrmc(Y_m,mask_m,niter=niter_mc,fun=cost_fun)

cost_matrix = stats[:,0]
nrmse_matrix_tube = stats[:,1]
times_matrix_tube = stats[:,2]

print('Time elapsed: Mat Comp: {:.3f} '.format(tElapsed_matrix))
print('Final NRMSE: Mat Comp: {:.8f} '.format(nrmse_matrix_tube[-1]))
# Out:
# Time elapsed: Mat Comp: 30.113
# Final NRMSE: Mat Comp: 0.00000001

# %%
## GROUSE

rank = r*n3
# rank = r
fun = lambda X: [0, np.linalg.norm(X - L_m, 'fro') / np.linalg.norm(L_m, 'fro')]
Ym_hat_grouse, stats_grouse, tElapsed_grouse = grouse(Y_m, mask_m, rank,outer=10,mode="batch",fun=fun,randomOrder=False,
                                                      verbose=False)
grouse_nrmse = np.linalg.norm(Ym_hat_grouse - L_m,'fro') / np.linalg.norm(L_m,'fro')
print('GROUSE Time: {:4f}'.format(tElapsed_grouse))
print('GROUSE NRMSE: {:4f}'.format(grouse_nrmse))
        
nrmse_grouse_tube = stats_grouse[:,1]
times_grouse_tube = stats_grouse[:,-1]
tElapsed_grouse = np.sum(times_grouse)
plt.semilogy(nrmse_grouse_tube)
plt.title('GROUSE: Recovered Tensor NRMSE')
plt.xlabel('Iteration')
plt.show()
# Out:
# GROUSE Time: 30.424001
# GROUSE NRMSE: 0.000004

# %%
## TOUCAN
# Y = Tensor(L.array() * mask)

fun = lambda X,k: [0, tfrobnorm(X - L) / Lfrob]
# fun = lambda X,k: [0, tfrobnorm_array(X - L.array()[:,k,:]) / tfrobnorm_array(L.array()[:,k,:])]
Y_hat_toucan, U, stats_toucan, tElapsed_toucan = toucan(Y,mask,rank=r,tube=tube,outer=5,mode="batch",tol=tol,cgiter = None,cgtol=tol,fun=fun,
                                                     randomOrder=False,verbose=False)

toucan_nrmse = tfrobnorm(Y_hat_toucan - L) / Lfrob
print('TOUCAN Time: {:4f}'.format(tElapsed_toucan))
print('TOUCAN NRMSE: {:8f}'.format(toucan_nrmse))

nrmse_toucan_tube = stats_toucan[:,1]
cgiter_toucan = stats_toucan[:,2]
times_toucan_tube = stats_toucan[:,-1]
# Out:
# TOUCAN Time: 2.186413
# TOUCAN NRMSE: 0.000000

# %%
plt.figure(figsize=(13,4),tight_layout=True)
plt.semilogy(np.cumsum(times_toucan), nrmse_toucan, '#ff7f0e',label='TOUCAN')
plt.semilogy(np.cumsum(times_toucan_tube), nrmse_toucan_tube, '#ff7f0e',linestyle='--',label='TOUCAN')
plt.semilogy(np.cumsum(times_grouse), nrmse_grouse, 'b',label='GROUSE')
plt.semilogy(np.cumsum(times_grouse_tube), nrmse_grouse_tube, 'b',linestyle='--',label='GROUSE')
plt.semilogy(np.cumsum(times_tensor), nrmse_tensor, 'r',label='TNN-ADMM')
plt.semilogy(np.cumsum(times_tensor_tube), nrmse_tensor_tube, 'r',linestyle='--',label='TNN-ADMM')
plt.semilogy(np.cumsum(times_tctf), nrmse_tctf, 'k',label='TCTF')
plt.semilogy(np.cumsum(times_tctf_tube), nrmse_tctf_tube, 'k',linestyle='--',label='TCTF')
plt.semilogy(np.cumsum(times_matrix), nrmse_matrix, 'g',label='MatComp')
plt.semilogy(np.cumsum(times_matrix_tube), nrmse_matrix_tube, 'g',linestyle="--",label='Matcomp')

max_time = max(max(np.cumsum(times_matrix)),max(np.cumsum(times_tctf)),max(np.cumsum(times_tensor)),max(np.cumsum(times_grouse)))
# max_time = max(max(np.cumsum(times_tctf)),max(np.cumsum(times_tensor)),max(np.cumsum(times_toucan)))
plt.xlabel('Time (s)')
plt.ylabel('NRMSE')
# plt.xticks(np.arange(0, max_time, step=10))
plt.xticks(np.arange(0, max_time, step=2))
handles, labels = plt.gca().get_legend_handles_labels()
ids = [0,2,4,6,8]
# ids = [0,2,4]
handles = [handles[i] for i in ids]
labels = [labels[i] for i in ids]
plt.legend(handles, labels, bbox_to_anchor=(1.5,0.5),loc='center right')
plt.rcParams.update({'font.size': 22})

if(tube is False):
    name = 'nrmse_times_rand_sample_' + str(r) + '-' + str(n1) + '-' + str(n2) + '-' + str(n3) + '-' + str(int(rho*100)) + '%.eps'
else:
    name = 'nrmse_times_tube_sample_' + str(r) + '-' + str(n1) + '-' + str(n2) + '-' + str(n3) + '-' + str(int(rho*100)) + '%.eps'
plt.savefig(name)
plt.show()

# %% [markdown]
# ### Dynamically changing free submodule in time

# %%
# ### Synthetic data sizes
# ranks = [2, 4, 6, 8]
# # ranks = [2, 4]
# # ranks = [1, 3, 5, 7]
# num_vec = 2000
# tube = False
# n1 = 50
# n3 = 10
# rho = 0.3
# sig = 0

# stats_toucan = np.zeros((len(ranks),num_vec))

# plt.figure(figsize=(12,4),tight_layout=True)
# ax = plt.subplot(111)

# if(tube is True):
#     name = 'nrmse_tracking_tube_sample-' + str(n1) + '-' + str(n3) + '-' + str(int(rho*100)) + '%.eps'
# else:
#     name = 'nrmse_tracking_rand_sample-' + str(n1) + '-' + str(n3) + '-' + str(int(rho*100)) + '%.eps'

# for rank in range(0,len(ranks)):

#     r = ranks[rank]

#     ### Initialize U
#     np.random.seed(10)
#     K = r
#     U = tsvd(Tensor(np.random.randn(n1,r,n3)),full=False)[0]
#     U = Tensor(U.array()[:,:K,:])

#     tStart = time.time()
#     iter = 0
#     for t in range(0,num_vec):

#         if(t % 500 == 0):
#             P = tsvd(Tensor(np.random.randn(n1,r,n3)),full=False)[0]
#             Utrue = Tensor(P.array()[:,:r,:])
#             Utrue_frob = tfrobnorm(Utrue * Utrue.T())

#         Wtrue = Tensor(np.random.randn(r, 1, n3))
#         Yvec = Utrue * Wtrue + Tensor(sig * np.random.randn(n1,1,n3))
        
#         if(tube): #Tubal sampling
#             mask = np.random.rand(n1, 1)
#             mask[mask > rho] = 1
#             mask[mask <= rho] = 0
#             mask = mask.astype(int)
#             mask = np.repeat(mask[:, :, np.newaxis], n3, axis=2)
#             idx = np.where(mask[:,0,0] > 0)[0]
            
#             tStart = time.time()
#             U,w = toucan_stream_tube(Yvec,idx,U)
#             tEnd = time.time()
#             tElapsed = tEnd - tStart
        
#         else: #random entry sampling
#             mask = np.random.rand(n1, n3)
#             mask[mask > rho] = 1
#             mask[mask <= rho] = 0
#             mask = mask.astype(int)
            
#             tStart = time.time()
#             U,w,cg_iters = toucan_stream(Yvec,mask,U)
#             tEnd = time.time()
#             tElapsed = tEnd - tStart

#         stats_toucan[rank,iter] = tfrobnorm(Utrue * Utrue.T() - U * U.T()) / Utrue_frob
#         iter += 1

#         nrmse_toucan = stats_toucan[rank,:]

#     ax.semilogy(stats_toucan[rank,:],label='$rank = %r$'%r)
# # ax.set_title('TOUCAN: Free Submodule Error')
# ax.set_xlabel('Iteration')
# ax.set_ylabel('NRMSE')
# # Shrink current axis by 20%
# # box = ax.get_position()
# # ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

# # Put a legend to the right of the current axis
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# plt.rcParams.update({'font.size': 22})
# plt.savefig(name)
# plt.show()

# %%
# from cp_wopt import *
from tecpsgd import *
from tsvd import *

# %%
# r = 1
r = 2
# r = 5
# r =  10
n1 = 100
n2 = 100
n3 = 100
np.random.seed(0)
# L = synth_tensor(r,n1,n2,n3)

# A=np.random.randn(n1, r) 
# A = A / np.linalg.norm(A,axis=0)
# B=np.random.randn(n2, r)
# B = B / np.linalg.norm(B,axis=0)
# C=np.random.randn(n3, r)
# C = C / np.linalg.norm(C,axis=0)

A=np.random.randn(n1, r)
B=np.random.randn(n2, r)
C=np.random.randn(n3, r)

#Create observed tensor that follows PARAFAC model
L_cp = np.zeros((n1,n2,n3))
for k in range(0,n3):
    L_cp[:,:,k]=A@np.diag(C[k,:])@B.T

tube = False
rho = 0.5  # percentage of missing entries
# rho = 1 - r*n3 / (n1*n3)
print(rho)

if(tube is False):
    mask = np.random.rand(n1, n2, n3)
    mask[mask > rho] = 1
    mask[mask <= rho] = 0
    mask = mask.astype(int)
else:
    mask = np.random.rand(n1, n2)
    mask[mask > rho] = 1
    mask[mask <= rho] = 0
    mask = mask.astype(int)
    mask = np.repeat(mask[:, :, np.newaxis], n3, axis=2)
    
sig = 0

L_cp += sig*np.random.randn(n1,n2,n3)

L_cp_frob = tfrobnorm(Tensor(L_cp))
# Out:
# 0.5

# %%
### TeCPSGD

# Tensor_Y_Noiseless = np.transpose(L.array(),[0,2,1])
Tensor_Y_Noiseless = L_cp.copy()
rank = r
# OmegaTensor = np.transpose(mask,[0,2,1])
OmegaTensor = mask.copy()
# tensor_dims = [n1,n3,n2]
tensor_dims = [n1,n2,n3]
maxepochs = 5
tolcost = 1e-14
permute_on = False

options = {
    'maxepochs': maxepochs,
    'tolcost': tolcost,
    'lam': 0.001,
    'stepsize': 0.5,
#     'mu': 0.05,
    'permute_on':  permute_on,
    'store_subinfo': True,
    'store_matrix': False,
    'verbose': True
}

fun = lambda X: np.sqrt(np.sum((X - L_cp)**2)) / L_cp_frob

Xinit = {
    'A': np.random.randn(tensor_dims[0], rank),
    'B': np.random.randn(tensor_dims[1], rank),
    'C': np.random.randn(tensor_dims[2], rank)
}


Xsol_TeCPSGD, Y_hat_tecpsgd, info_TeCPSGD, sub_infos_TeCPSGD = TeCPSGD(Tensor_Y_Noiseless, OmegaTensor, None, tensor_dims, rank,
                                                          Xinit, options,fun=fun)

A_t0 = Xsol_TeCPSGD['A']
B_t0 = Xsol_TeCPSGD['B']
C_t0 = Xsol_TeCPSGD['C']


nrmse_tecpsgd = sub_infos_TeCPSGD['error'][1:]

# idx = np.where(nrmse_tecpsgd > tol)[0]
# nrmse_tecpsgd = nrmse_tecpsgd[idx]
times_tecpsgd = sub_infos_TeCPSGD['times'][1:]
# times_tecpsgd = times_tecpsgd[idx]
# Out:
# TeCPSGD [0.500000] Epoch 000, Cost 1082674.54481, Cost(test) 0.00000, Stepsize 0.00000
# TeCPSGD: fnum =   1, cost = 0.000, error = 1.00022277
# TeCPSGD: fnum =   2, cost = 0.000, error = 0.99926930
# TeCPSGD: fnum =   3, cost = 0.000, error = 0.84358630
# TeCPSGD: fnum =   4, cost = 0.000, error = 0.62747361
# TeCPSGD: fnum =   5, cost = 0.000, error = 0.98242760
# TeCPSGD: fnum =   6, cost = 0.000, error = 0.70282231
# TeCPSGD: fnum =   7, cost = 0.000, error = 0.74574097
# TeCPSGD: fnum =   8, cost = 0.000, error = 0.44986402
# TeCPSGD: fnum =   9, cost = 0.000, error = 0.43294129
# TeCPSGD: fnum =  10, cost = 0.000, error = 0.73539406
# TeCPSGD: fnum =  11, cost = 0.000, error = 0.51843382
# TeCPSGD: fnum =  12, cost = 0.000, error = 0.20049513
# TeCPSGD: fnum =  13, cost = 0.000, error = 0.58879733
# TeCPSGD: fnum =  14, cost = 0.000, error = 0.84167963
# TeCPSGD: fnum =  15, cost = 0.000, error = 0.37513568
# TeCPSGD: fnum =  16, cost = 0.000, error = 0.74951753
# TeCPSGD: fnum =  17, cost = 0.000, error = 0.25302027
# TeCPSGD: fnum =  18, cost = 0.000, error = 0.23997090
# TeCPSGD: fnum =  19, cost = 0.000, error = 0.05317500
# TeCPSGD: fnum =  20, cost = 0.000, error = 0.08215555
# TeCPSGD: fnum =  21, cost = 0.000, error = 0.60952433
# TeCPSGD: fnum =  22, cost = 0.000, error = 0.58419298
# TeCPSGD: fnum =  23, cost = 0.000, error = 0.08534259
# TeCPSGD: fnum =  24, cost = 0.000, error = 0.46974836
# TeCPSGD: fnum =  25, cost = 0.000, error = 0.07441122
# TeCPSGD: fnum =  26, cost = 0.000, error = 0.26601238
# TeCPSGD: fnum =  27, cost = 0.000, error = 0.22082717
# TeCPSGD: fnum =  28, cost = 0.000, error = 0.10439687
# TeCPSGD: fnum =  29, cost = 0.000, error = 0.05089869
# TeCPSGD: fnum =  30, cost = 0.000, error = 0.02912610
# TeCPSGD: fnum =  31, cost = 0.000, error = 0.03563983
# TeCPSGD: fnum =  32, cost = 0.000, error = 0.02493810
# TeCPSGD: fnum =  33, cost = 0.000, error = 0.02893248
# TeCPSGD: fnum =  34, cost = 0.000, error = 0.01765565
# TeCPSGD: fnum =  35, cost = 0.000, error = 0.01477216
# TeCPSGD: fnum =  36, cost = 0.000, error = 0.01340062
# TeCPSGD: fnum =  37, cost = 0.000, error = 0.01758608
# TeCPSGD: fnum =  38, cost = 0.000, error = 0.00842724
# TeCPSGD: fnum =  39, cost = 0.000, error = 0.00569706
# TeCPSGD: fnum =  40, cost = 0.000, error = 0.00382320
# TeCPSGD: fnum =  41, cost = 0.000, error = 0.00514947
# TeCPSGD: fnum =  42, cost = 0.000, error = 0.00256595
# TeCPSGD: fnum =  43, cost = 0.000, error = 0.00676221
# TeCPSGD: fnum =  44, cost = 0.000, error = 0.00212927
# TeCPSGD: fnum =  45, cost = 0.000, error = 0.00624655
# TeCPSGD: fnum =  46, cost = 0.000, error = 0.00187932
# TeCPSGD: fnum =  47, cost = 0.000, error = 0.00245430
# TeCPSGD: fnum =  48, cost = 0.000, error = 0.00236135
# TeCPSGD: fnum =  49, cost = 0.000, error = 0.00247067
# TeCPSGD: fnum =  50, cost = 0.000, error = 0.00105857
# TeCPSGD: fnum =  51, cost = 0.000, error = 0.00095224
# TeCPSGD: fnum =  52, cost = 0.000, error = 0.00069788
# TeCPSGD: fnum =  53, cost = 0.000, error = 0.00231643
# TeCPSGD: fnum =  54, cost = 0.000, error = 0.00084696
# TeCPSGD: fnum =  55, cost = 0.000, error = 0.00035647
# TeCPSGD: fnum =  56, cost = 0.000, error = 0.00022553
# TeCPSGD: fnum =  57, cost = 0.000, error = 0.00008425
# TeCPSGD: fnum =  58, cost = 0.000, error = 0.00007736
# TeCPSGD: fnum =  59, cost = 0.000, error = 0.00006030
# TeCPSGD: fnum =  60, cost = 0.000, error = 0.00001163
# TeCPSGD: fnum =  61, cost = 0.000, error = 0.00001221
# TeCPSGD: fnum =  62, cost = 0.000, error = 0.00002994
# TeCPSGD: fnum =  63, cost = 0.000, error = 0.00002373
# TeCPSGD: fnum =  64, cost = 0.000, error = 0.00000768
# TeCPSGD: fnum =  65, cost = 0.000, error = 0.00002498
# TeCPSGD: fnum =  66, cost = 0.000, error = 0.00003983
# TeCPSGD: fnum =  67, cost = 0.000, error = 0.00001264
# TeCPSGD: fnum =  68, cost = 0.000, error = 0.00000306
# TeCPSGD: fnum =  69, cost = 0.000, error = 0.00000320
# TeCPSGD: fnum =  70, cost = 0.000, error = 0.00000295
# TeCPSGD: fnum =  71, cost = 0.000, error = 0.00000477
# TeCPSGD: fnum =  72, cost = 0.000, error = 0.00000170
# TeCPSGD: fnum =  73, cost = 0.000, error = 0.00000184
# TeCPSGD: fnum =  74, cost = 0.000, error = 0.00000257
# TeCPSGD: fnum =  75, cost = 0.000, error = 0.00000071
# TeCPSGD: fnum =  76, cost = 0.000, error = 0.00000178
# TeCPSGD: fnum =  77, cost = 0.000, error = 0.00000041
# TeCPSGD: fnum =  78, cost = 0.000, error = 0.00000067
# TeCPSGD: fnum =  79, cost = 0.000, error = 0.00000226
# TeCPSGD: fnum =  80, cost = 0.000, error = 0.00000033
# TeCPSGD: fnum =  81, cost = 0.000, error = 0.00000087
# TeCPSGD: fnum =  82, cost = 0.000, error = 0.00000035
# TeCPSGD: fnum =  83, cost = 0.000, error = 0.00000075
# TeCPSGD: fnum =  84, cost = 0.000, error = 0.00000065
# TeCPSGD: fnum =  85, cost = 0.000, error = 0.00000035
# TeCPSGD: fnum =  86, cost = 0.000, error = 0.00000009
# TeCPSGD: fnum =  87, cost = 0.000, error = 0.00000018
# TeCPSGD: fnum =  88, cost = 0.000, error = 0.00000049
# TeCPSGD: fnum =  89, cost = 0.000, error = 0.00000021
# TeCPSGD: fnum =  90, cost = 0.000, error = 0.00000007
# TeCPSGD: fnum =  91, cost = 0.000, error = 0.00000034
# TeCPSGD: fnum =  92, cost = 0.000, error = 0.00000007
# TeCPSGD: fnum =  93, cost = 0.000, error = 0.00000020
# TeCPSGD: fnum =  94, cost = 0.000, error = 0.00000010
# TeCPSGD: fnum =  95, cost = 0.000, error = 0.00000033
# TeCPSGD: fnum =  96, cost = 0.000, error = 0.00000016
# TeCPSGD: fnum =  97, cost = 0.000, error = 0.00000020
# TeCPSGD: fnum =  98, cost = 0.000, error = 0.00000011
# TeCPSGD: fnum =  99, cost = 0.000, error = 0.00000005
# TeCPSGD: fnum = 100, cost = 0.000, error = 0.00000004
# TeCPSGD [0.500000] Epoch   0, Cost 0.0000000, Cost(test) 0.0000000, Stepsize 0.4761905
# TeCPSGD: fnum = 101, cost = 0.000, error = 0.00000008
# TeCPSGD: fnum = 102, cost = 0.000, error = 0.00000004
# TeCPSGD: fnum = 103, cost = 0.000, error = 0.00000008
# TeCPSGD: fnum = 104, cost = 0.000, error = 0.00000008
# TeCPSGD: fnum = 105, cost = 0.000, error = 0.00000011
# TeCPSGD: fnum = 106, cost = 0.000, error = 0.00000002
# TeCPSGD: fnum = 107, cost = 0.000, error = 0.00000009
# TeCPSGD: fnum = 108, cost = 0.000, error = 0.00000005
# TeCPSGD: fnum = 109, cost = 0.000, error = 0.00000004
# TeCPSGD: fnum = 110, cost = 0.000, error = 0.00000001
# TeCPSGD: fnum = 111, cost = 0.000, error = 0.00000002
# TeCPSGD: fnum = 112, cost = 0.000, error = 0.00000007
# TeCPSGD: fnum = 113, cost = 0.000, error = 0.00000003
# TeCPSGD: fnum = 114, cost = 0.000, error = 0.00000006
# TeCPSGD: fnum = 115, cost = 0.000, error = 0.00000009
# TeCPSGD: fnum = 116, cost = 0.000, error = 0.00000001
# TeCPSGD: fnum = 117, cost = 0.000, error = 0.00000005
# TeCPSGD: fnum = 118, cost = 0.000, error = 0.00000003
# TeCPSGD: fnum = 119, cost = 0.000, error = 0.00000002
# TeCPSGD: fnum = 120, cost = 0.000, error = 0.00000001
# TeCPSGD: fnum = 121, cost = 0.000, error = 0.00000001
# TeCPSGD: fnum = 122, cost = 0.000, error = 0.00000002
# TeCPSGD: fnum = 123, cost = 0.000, error = 0.00000001
# TeCPSGD: fnum = 124, cost = 0.000, error = 0.00000001
# TeCPSGD: fnum = 125, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 126, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 127, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 128, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 129, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 130, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 131, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 132, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 133, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 134, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 135, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 136, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 137, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 138, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 139, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 140, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 141, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 142, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 143, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 144, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 145, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 146, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 147, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 148, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 149, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 150, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 151, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 152, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 153, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 154, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 155, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 156, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 157, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 158, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 159, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 160, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 161, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 162, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 163, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 164, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 165, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 166, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 167, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 168, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 169, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 170, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 171, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 172, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 173, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 174, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 175, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 176, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 177, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 178, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 179, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 180, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 181, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 182, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 183, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 184, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 185, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 186, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 187, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 188, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 189, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 190, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 191, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 192, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 193, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 194, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 195, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 196, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 197, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 198, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 199, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 200, cost = 0.000, error = 0.00000000
# TeCPSGD [0.500000] Epoch   1, Cost 0.0000000, Cost(test) 0.0000000, Stepsize 0.4545455
# TeCPSGD: fnum = 201, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 202, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 203, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 204, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 205, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 206, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 207, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 208, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 209, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 210, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 211, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 212, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 213, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 214, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 215, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 216, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 217, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 218, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 219, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 220, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 221, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 222, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 223, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 224, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 225, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 226, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 227, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 228, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 229, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 230, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 231, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 232, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 233, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 234, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 235, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 236, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 237, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 238, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 239, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 240, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 241, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 242, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 243, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 244, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 245, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 246, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 247, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 248, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 249, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 250, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 251, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 252, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 253, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 254, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 255, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 256, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 257, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 258, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 259, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 260, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 261, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 262, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 263, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 264, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 265, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 266, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 267, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 268, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 269, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 270, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 271, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 272, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 273, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 274, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 275, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 276, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 277, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 278, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 279, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 280, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 281, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 282, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 283, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 284, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 285, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 286, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 287, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 288, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 289, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 290, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 291, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 292, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 293, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 294, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 295, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 296, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 297, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 298, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 299, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 300, cost = 0.000, error = 0.00000000
# TeCPSGD [0.500000] Epoch   2, Cost 0.0000000, Cost(test) 0.0000000, Stepsize 0.4347826
# TeCPSGD: fnum = 301, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 302, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 303, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 304, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 305, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 306, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 307, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 308, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 309, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 310, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 311, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 312, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 313, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 314, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 315, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 316, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 317, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 318, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 319, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 320, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 321, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 322, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 323, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 324, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 325, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 326, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 327, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 328, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 329, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 330, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 331, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 332, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 333, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 334, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 335, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 336, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 337, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 338, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 339, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 340, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 341, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 342, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 343, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 344, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 345, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 346, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 347, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 348, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 349, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 350, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 351, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 352, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 353, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 354, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 355, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 356, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 357, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 358, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 359, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 360, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 361, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 362, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 363, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 364, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 365, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 366, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 367, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 368, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 369, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 370, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 371, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 372, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 373, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 374, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 375, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 376, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 377, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 378, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 379, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 380, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 381, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 382, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 383, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 384, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 385, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 386, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 387, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 388, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 389, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 390, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 391, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 392, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 393, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 394, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 395, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 396, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 397, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 398, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 399, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 400, cost = 0.000, error = 0.00000000
# TeCPSGD [0.500000] Epoch   3, Cost 0.0000000, Cost(test) 0.0000000, Stepsize 0.4166667
# TeCPSGD: fnum = 401, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 402, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 403, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 404, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 405, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 406, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 407, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 408, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 409, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 410, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 411, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 412, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 413, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 414, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 415, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 416, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 417, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 418, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 419, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 420, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 421, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 422, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 423, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 424, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 425, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 426, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 427, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 428, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 429, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 430, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 431, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 432, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 433, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 434, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 435, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 436, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 437, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 438, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 439, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 440, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 441, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 442, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 443, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 444, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 445, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 446, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 447, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 448, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 449, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 450, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 451, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 452, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 453, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 454, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 455, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 456, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 457, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 458, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 459, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 460, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 461, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 462, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 463, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 464, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 465, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 466, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 467, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 468, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 469, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 470, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 471, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 472, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 473, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 474, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 475, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 476, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 477, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 478, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 479, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 480, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 481, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 482, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 483, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 484, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 485, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 486, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 487, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 488, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 489, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 490, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 491, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 492, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 493, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 494, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 495, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 496, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 497, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 498, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 499, cost = 0.000, error = 0.00000000
# TeCPSGD: fnum = 500, cost = 0.000, error = 0.00000000
# TeCPSGD [0.500000] Epoch   4, Cost 0.0000000, Cost(test) 0.0000000, Stepsize 0.4000000

# %%
tol = 1e-9
idx = np.where(nrmse_tecpsgd > tol)[0]
nrmse_tecpsgd = nrmse_tecpsgd[idx]
times_tecpsgd = times_tecpsgd[idx]

# %%
### OLSTEC

from olstec import *

rank = r
maxepochs = 5
tolcost = 1e-14
permute_on = False

options = {
    'maxepochs': maxepochs,
    'tolcost': tolcost,
    'lam': 1,
    'stepsize': 0.7,
    'mu': 0.01,
    'permute_on':  permute_on,
    'store_subinfo': True,
    'store_matrix': False,
    'verbose': True,
    'tw_flag': None,
    'tw_len': None
}

np.random.seed(0)
Xinit = {
    'A': np.random.randn(tensor_dims[0], rank),
    'B': np.random.randn(tensor_dims[1], rank),
    'C': np.random.randn(tensor_dims[2], rank)
}

print(Tensor_Y_Noiseless.shape)
Xsol_olstec, Y_hat_olstec, info_olstec, sub_infos_olstec = OLSTEC(Tensor_Y_Noiseless, OmegaTensor, None, tensor_dims, rank,
                                                          Xinit, options, fun=fun)

A_t0 = Xsol_olstec['A']
B_t0 = Xsol_olstec['B']
C_t0 = Xsol_olstec['C']

nrmse_olstec = sub_infos_olstec['error'][1:]
times_olstec = sub_infos_olstec['times'][1:]
# Out:
# (100, 100, 100)
# TeCPSGD Epoch 000, Cost 0.00000, Cost(test) 0.00000
# OLSTEC: fnum =   1, cost = 0.000, error = 0.00000002
# OLSTEC: fnum =   2, cost = 0.000, error = 0.00007168
# OLSTEC: fnum =   3, cost = 0.000, error = 0.00003729
# OLSTEC: fnum =   4, cost = 0.000, error = 0.00015337
# OLSTEC: fnum =   5, cost = 0.000, error = 0.00011190
# OLSTEC: fnum =   6, cost = 0.000, error = 0.00010724
# OLSTEC: fnum =   7, cost = 0.000, error = 0.00020366
# OLSTEC: fnum =   8, cost = 0.000, error = 0.00010947
# OLSTEC: fnum =   9, cost = 0.000, error = 0.00019499
# OLSTEC: fnum =  10, cost = 0.000, error = 0.00009978
# OLSTEC: fnum =  11, cost = 0.000, error = 0.00017469
# OLSTEC: fnum =  12, cost = 0.000, error = 0.00011411
# OLSTEC: fnum =  13, cost = 0.000, error = 0.00020618
# OLSTEC: fnum =  14, cost = 0.000, error = 0.00008124
# OLSTEC: fnum =  15, cost = 0.000, error = 0.00019148
# OLSTEC: fnum =  16, cost = 0.000, error = 0.00017182
# OLSTEC: fnum =  17, cost = 0.000, error = 0.00019902
# OLSTEC: fnum =  18, cost = 0.000, error = 0.00018302
# OLSTEC: fnum =  19, cost = 0.000, error = 0.00017793
# OLSTEC: fnum =  20, cost = 0.000, error = 0.00018686
# OLSTEC: fnum =  21, cost = 0.000, error = 0.00018620
# OLSTEC: fnum =  22, cost = 0.000, error = 0.00021858
# OLSTEC: fnum =  23, cost = 0.000, error = 0.00018152
# OLSTEC: fnum =  24, cost = 0.000, error = 0.00018784
# OLSTEC: fnum =  25, cost = 0.000, error = 0.00019807
# OLSTEC: fnum =  26, cost = 0.000, error = 0.00019415
# OLSTEC: fnum =  27, cost = 0.000, error = 0.00019811
# OLSTEC: fnum =  28, cost = 0.000, error = 0.00015062
# OLSTEC: fnum =  29, cost = 0.000, error = 0.00015352
# OLSTEC: fnum =  30, cost = 0.000, error = 0.00019225
# OLSTEC: fnum =  31, cost = 0.000, error = 0.00021393
# OLSTEC: fnum =  32, cost = 0.000, error = 0.00019936
# OLSTEC: fnum =  33, cost = 0.000, error = 0.00015953
# OLSTEC: fnum =  34, cost = 0.000, error = 0.00019917
# OLSTEC: fnum =  35, cost = 0.000, error = 0.00014640
# OLSTEC: fnum =  36, cost = 0.000, error = 0.00016193
# OLSTEC: fnum =  37, cost = 0.000, error = 0.00020620
# OLSTEC: fnum =  38, cost = 0.000, error = 0.00017844
# OLSTEC: fnum =  39, cost = 0.000, error = 0.00019082
# OLSTEC: fnum =  40, cost = 0.000, error = 0.00019065
# OLSTEC: fnum =  41, cost = 0.000, error = 0.00020553
# OLSTEC: fnum =  42, cost = 0.000, error = 0.00020116
# OLSTEC: fnum =  43, cost = 0.000, error = 0.00016239
# OLSTEC: fnum =  44, cost = 0.000, error = 0.00019017
# OLSTEC: fnum =  45, cost = 0.000, error = 0.00022158
# OLSTEC: fnum =  46, cost = 0.000, error = 0.00019806
# OLSTEC: fnum =  47, cost = 0.000, error = 0.00019453
# OLSTEC: fnum =  48, cost = 0.000, error = 0.00015574
# OLSTEC: fnum =  49, cost = 0.000, error = 0.00020268
# OLSTEC: fnum =  50, cost = 0.000, error = 0.00018937
# OLSTEC: fnum =  51, cost = 0.000, error = 0.00020341
# OLSTEC: fnum =  52, cost = 0.000, error = 0.00019378
# OLSTEC: fnum =  53, cost = 0.000, error = 0.00021271
# OLSTEC: fnum =  54, cost = 0.000, error = 0.00019220
# OLSTEC: fnum =  55, cost = 0.000, error = 0.00019309
# OLSTEC: fnum =  56, cost = 0.000, error = 0.00020103
# OLSTEC: fnum =  57, cost = 0.000, error = 0.00019550
# OLSTEC: fnum =  58, cost = 0.000, error = 0.00020050
# OLSTEC: fnum =  59, cost = 0.000, error = 0.00021236
# OLSTEC: fnum =  60, cost = 0.000, error = 0.00020523
# OLSTEC: fnum =  61, cost = 0.000, error = 0.00020649
# OLSTEC: fnum =  62, cost = 0.000, error = 0.00019112
# OLSTEC: fnum =  63, cost = 0.000, error = 0.00022283
# OLSTEC: fnum =  64, cost = 0.000, error = 0.00020282
# OLSTEC: fnum =  65, cost = 0.000, error = 0.00018014
# OLSTEC: fnum =  66, cost = 0.000, error = 0.00018041
# OLSTEC: fnum =  67, cost = 0.000, error = 0.00019291
# OLSTEC: fnum =  68, cost = 0.000, error = 0.00019685
# OLSTEC: fnum =  69, cost = 0.000, error = 0.00020592
# OLSTEC: fnum =  70, cost = 0.000, error = 0.00020366
# OLSTEC: fnum =  71, cost = 0.000, error = 0.00020867
# OLSTEC: fnum =  72, cost = 0.000, error = 0.00021407
# OLSTEC: fnum =  73, cost = 0.000, error = 0.00021118
# OLSTEC: fnum =  74, cost = 0.000, error = 0.00019043
# OLSTEC: fnum =  75, cost = 0.000, error = 0.00019783
# OLSTEC: fnum =  76, cost = 0.000, error = 0.00020630
# OLSTEC: fnum =  77, cost = 0.000, error = 0.00019637
# OLSTEC: fnum =  78, cost = 0.000, error = 0.00021398
# OLSTEC: fnum =  79, cost = 0.000, error = 0.00016784
# OLSTEC: fnum =  80, cost = 0.000, error = 0.00019955
# OLSTEC: fnum =  81, cost = 0.000, error = 0.00019657
# OLSTEC: fnum =  82, cost = 0.000, error = 0.00020303
# OLSTEC: fnum =  83, cost = 0.000, error = 0.00019508
# OLSTEC: fnum =  84, cost = 0.000, error = 0.00021105
# OLSTEC: fnum =  85, cost = 0.000, error = 0.00022792
# OLSTEC: fnum =  86, cost = 0.000, error = 0.00020414
# OLSTEC: fnum =  87, cost = 0.000, error = 0.00021638
# OLSTEC: fnum =  88, cost = 0.000, error = 0.00020629
# OLSTEC: fnum =  89, cost = 0.000, error = 0.00020670
# OLSTEC: fnum =  90, cost = 0.000, error = 0.00021575
# OLSTEC: fnum =  91, cost = 0.000, error = 0.00020188
# OLSTEC: fnum =  92, cost = 0.000, error = 0.00019773
# OLSTEC: fnum =  93, cost = 0.000, error = 0.00020956
# OLSTEC: fnum =  94, cost = 0.000, error = 0.00020592
# OLSTEC: fnum =  95, cost = 0.000, error = 0.00017630
# OLSTEC: fnum =  96, cost = 0.000, error = 0.00021015
# OLSTEC: fnum =  97, cost = 0.000, error = 0.00022267
# OLSTEC: fnum =  98, cost = 0.000, error = 0.00020726
# OLSTEC: fnum =  99, cost = 0.000, error = 0.00020491
# OLSTEC: fnum = 100, cost = 0.000, error = 0.00020109
# OLSTEC Epoch   0, Cost 0.0000000, Cost(test) 0.0000000
# OLSTEC: fnum = 101, cost = 0.000, error = 0.00021504
# OLSTEC: fnum = 102, cost = 0.000, error = 0.00019545
# OLSTEC: fnum = 103, cost = 0.000, error = 0.00018761
# OLSTEC: fnum = 104, cost = 0.000, error = 0.00020255
# OLSTEC: fnum = 105, cost = 0.000, error = 0.00021185
# OLSTEC: fnum = 106, cost = 0.000, error = 0.00019841
# OLSTEC: fnum = 107, cost = 0.000, error = 0.00020933
# OLSTEC: fnum = 108, cost = 0.000, error = 0.00019346
# OLSTEC: fnum = 109, cost = 0.000, error = 0.00019838
# OLSTEC: fnum = 110, cost = 0.000, error = 0.00019637
# OLSTEC: fnum = 111, cost = 0.000, error = 0.00019529
# OLSTEC: fnum = 112, cost = 0.000, error = 0.00018537
# OLSTEC: fnum = 113, cost = 0.000, error = 0.00020561
# OLSTEC: fnum = 114, cost = 0.000, error = 0.00019780
# OLSTEC: fnum = 115, cost = 0.000, error = 0.00019560
# OLSTEC: fnum = 116, cost = 0.000, error = 0.00021104
# OLSTEC: fnum = 117, cost = 0.000, error = 0.00020978
# OLSTEC: fnum = 118, cost = 0.000, error = 0.00019613
# OLSTEC: fnum = 119, cost = 0.000, error = 0.00018739
# OLSTEC: fnum = 120, cost = 0.000, error = 0.00019565
# OLSTEC: fnum = 121, cost = 0.000, error = 0.00021019
# OLSTEC: fnum = 122, cost = 0.000, error = 0.00021839
# OLSTEC: fnum = 123, cost = 0.000, error = 0.00019201
# OLSTEC: fnum = 124, cost = 0.000, error = 0.00020193
# OLSTEC: fnum = 125, cost = 0.000, error = 0.00020560
# OLSTEC: fnum = 126, cost = 0.000, error = 0.00020715
# OLSTEC: fnum = 127, cost = 0.000, error = 0.00020004
# OLSTEC: fnum = 128, cost = 0.000, error = 0.00020396
# OLSTEC: fnum = 129, cost = 0.000, error = 0.00020275
# OLSTEC: fnum = 130, cost = 0.000, error = 0.00019197
# OLSTEC: fnum = 131, cost = 0.000, error = 0.00022320
# OLSTEC: fnum = 132, cost = 0.000, error = 0.00020115
# OLSTEC: fnum = 133, cost = 0.000, error = 0.00020569
# OLSTEC: fnum = 134, cost = 0.000, error = 0.00020725
# OLSTEC: fnum = 135, cost = 0.000, error = 0.00018878
# OLSTEC: fnum = 136, cost = 0.000, error = 0.00018977
# OLSTEC: fnum = 137, cost = 0.000, error = 0.00020975
# OLSTEC: fnum = 138, cost = 0.000, error = 0.00019622
# OLSTEC: fnum = 139, cost = 0.000, error = 0.00020058
# OLSTEC: fnum = 140, cost = 0.000, error = 0.00019743
# OLSTEC: fnum = 141, cost = 0.000, error = 0.00021197
# OLSTEC: fnum = 142, cost = 0.000, error = 0.00020532
# OLSTEC: fnum = 143, cost = 0.000, error = 0.00019894
# OLSTEC: fnum = 144, cost = 0.000, error = 0.00020157
# OLSTEC: fnum = 145, cost = 0.000, error = 0.00022132
# OLSTEC: fnum = 146, cost = 0.000, error = 0.00020268
# OLSTEC: fnum = 147, cost = 0.000, error = 0.00020290
# OLSTEC: fnum = 148, cost = 0.000, error = 0.00018619
# OLSTEC: fnum = 149, cost = 0.000, error = 0.00020447
# OLSTEC: fnum = 150, cost = 0.000, error = 0.00019398
# OLSTEC: fnum = 151, cost = 0.000, error = 0.00020392
# OLSTEC: fnum = 152, cost = 0.000, error = 0.00019842
# OLSTEC: fnum = 153, cost = 0.000, error = 0.00021407
# OLSTEC: fnum = 154, cost = 0.000, error = 0.00020370
# OLSTEC: fnum = 155, cost = 0.000, error = 0.00020012
# OLSTEC: fnum = 156, cost = 0.000, error = 0.00020821
# OLSTEC: fnum = 157, cost = 0.000, error = 0.00020890
# OLSTEC: fnum = 158, cost = 0.000, error = 0.00020175
# OLSTEC: fnum = 159, cost = 0.000, error = 0.00021611
# OLSTEC: fnum = 160, cost = 0.000, error = 0.00021690
# OLSTEC: fnum = 161, cost = 0.000, error = 0.00020952
# OLSTEC: fnum = 162, cost = 0.000, error = 0.00019881
# OLSTEC: fnum = 163, cost = 0.000, error = 0.00022542
# OLSTEC: fnum = 164, cost = 0.000, error = 0.00020872
# OLSTEC: fnum = 165, cost = 0.000, error = 0.00019431
# OLSTEC: fnum = 166, cost = 0.000, error = 0.00019324
# OLSTEC: fnum = 167, cost = 0.000, error = 0.00019664
# OLSTEC: fnum = 168, cost = 0.000, error = 0.00020042
# OLSTEC: fnum = 169, cost = 0.000, error = 0.00020587
# OLSTEC: fnum = 170, cost = 0.000, error = 0.00020343
# OLSTEC: fnum = 171, cost = 0.000, error = 0.00021355
# OLSTEC: fnum = 172, cost = 0.000, error = 0.00022154
# OLSTEC: fnum = 173, cost = 0.000, error = 0.00021133
# OLSTEC: fnum = 174, cost = 0.000, error = 0.00020699
# OLSTEC: fnum = 175, cost = 0.000, error = 0.00020061
# OLSTEC: fnum = 176, cost = 0.000, error = 0.00020612
# OLSTEC: fnum = 177, cost = 0.000, error = 0.00019842
# OLSTEC: fnum = 178, cost = 0.000, error = 0.00021781
# OLSTEC: fnum = 179, cost = 0.000, error = 0.00017992
# OLSTEC: fnum = 180, cost = 0.000, error = 0.00020269
# OLSTEC: fnum = 181, cost = 0.000, error = 0.00020463
# OLSTEC: fnum = 182, cost = 0.000, error = 0.00021151
# OLSTEC: fnum = 183, cost = 0.000, error = 0.00019590
# OLSTEC: fnum = 184, cost = 0.000, error = 0.00021166
# OLSTEC: fnum = 185, cost = 0.000, error = 0.00022857
# OLSTEC: fnum = 186, cost = 0.000, error = 0.00021210
# OLSTEC: fnum = 187, cost = 0.000, error = 0.00021770
# OLSTEC: fnum = 188, cost = 0.000, error = 0.00020687
# OLSTEC: fnum = 189, cost = 0.000, error = 0.00020916
# OLSTEC: fnum = 190, cost = 0.000, error = 0.00021875
# OLSTEC: fnum = 191, cost = 0.000, error = 0.00020818
# OLSTEC: fnum = 192, cost = 0.000, error = 0.00019957
# OLSTEC: fnum = 193, cost = 0.000, error = 0.00020992
# OLSTEC: fnum = 194, cost = 0.000, error = 0.00020613
# OLSTEC: fnum = 195, cost = 0.000, error = 0.00019388
# OLSTEC: fnum = 196, cost = 0.000, error = 0.00021051
# OLSTEC: fnum = 197, cost = 0.000, error = 0.00022487
# OLSTEC: fnum = 198, cost = 0.000, error = 0.00020724
# OLSTEC: fnum = 199, cost = 0.000, error = 0.00020511
# OLSTEC: fnum = 200, cost = 0.000, error = 0.00020239
# OLSTEC Epoch   1, Cost 0.0000000, Cost(test) 0.0000000
# OLSTEC: fnum = 201, cost = 0.000, error = 0.00021717
# OLSTEC: fnum = 202, cost = 0.000, error = 0.00019624
# OLSTEC: fnum = 203, cost = 0.000, error = 0.00019294
# OLSTEC: fnum = 204, cost = 0.000, error = 0.00020359
# OLSTEC: fnum = 205, cost = 0.000, error = 0.00021293
# OLSTEC: fnum = 206, cost = 0.000, error = 0.00020130
# OLSTEC: fnum = 207, cost = 0.000, error = 0.00020922
# OLSTEC: fnum = 208, cost = 0.000, error = 0.00019781
# OLSTEC: fnum = 209, cost = 0.000, error = 0.00019843
# OLSTEC: fnum = 210, cost = 0.000, error = 0.00020114
# OLSTEC: fnum = 211, cost = 0.000, error = 0.00019632
# OLSTEC: fnum = 212, cost = 0.000, error = 0.00019153
# OLSTEC: fnum = 213, cost = 0.000, error = 0.00020544
# OLSTEC: fnum = 214, cost = 0.000, error = 0.00020908
# OLSTEC: fnum = 215, cost = 0.000, error = 0.00019592
# OLSTEC: fnum = 216, cost = 0.000, error = 0.00021393
# OLSTEC: fnum = 217, cost = 0.000, error = 0.00021064
# OLSTEC: fnum = 218, cost = 0.000, error = 0.00019730
# OLSTEC: fnum = 219, cost = 0.000, error = 0.00018826
# OLSTEC: fnum = 220, cost = 0.000, error = 0.00019643
# OLSTEC: fnum = 221, cost = 0.000, error = 0.00021196
# OLSTEC: fnum = 222, cost = 0.000, error = 0.00021823
# OLSTEC: fnum = 223, cost = 0.000, error = 0.00019292
# OLSTEC: fnum = 224, cost = 0.000, error = 0.00020305
# OLSTEC: fnum = 225, cost = 0.000, error = 0.00020630
# OLSTEC: fnum = 226, cost = 0.000, error = 0.00020834
# OLSTEC: fnum = 227, cost = 0.000, error = 0.00020008
# OLSTEC: fnum = 228, cost = 0.000, error = 0.00020983
# OLSTEC: fnum = 229, cost = 0.000, error = 0.00020917
# OLSTEC: fnum = 230, cost = 0.000, error = 0.00019189
# OLSTEC: fnum = 231, cost = 0.000, error = 0.00022425
# OLSTEC: fnum = 232, cost = 0.000, error = 0.00020124
# OLSTEC: fnum = 233, cost = 0.000, error = 0.00021291
# OLSTEC: fnum = 234, cost = 0.000, error = 0.00020819
# OLSTEC: fnum = 235, cost = 0.000, error = 0.00019489
# OLSTEC: fnum = 236, cost = 0.000, error = 0.00019410
# OLSTEC: fnum = 237, cost = 0.000, error = 0.00021024
# OLSTEC: fnum = 238, cost = 0.000, error = 0.00019902
# OLSTEC: fnum = 239, cost = 0.000, error = 0.00020215
# OLSTEC: fnum = 240, cost = 0.000, error = 0.00019853
# OLSTEC: fnum = 241, cost = 0.000, error = 0.00021295
# OLSTEC: fnum = 242, cost = 0.000, error = 0.00020596
# OLSTEC: fnum = 243, cost = 0.000, error = 0.00020614
# OLSTEC: fnum = 244, cost = 0.000, error = 0.00020359
# OLSTEC: fnum = 245, cost = 0.000, error = 0.00022119
# OLSTEC: fnum = 246, cost = 0.000, error = 0.00020349
# OLSTEC: fnum = 247, cost = 0.000, error = 0.00020443
# OLSTEC: fnum = 248, cost = 0.000, error = 0.00019286
# OLSTEC: fnum = 249, cost = 0.000, error = 0.00020481
# OLSTEC: fnum = 250, cost = 0.000, error = 0.00019492
# OLSTEC: fnum = 251, cost = 0.000, error = 0.00020398
# OLSTEC: fnum = 252, cost = 0.000, error = 0.00019938
# OLSTEC: fnum = 253, cost = 0.000, error = 0.00021427
# OLSTEC: fnum = 254, cost = 0.000, error = 0.00020612
# OLSTEC: fnum = 255, cost = 0.000, error = 0.00020159
# OLSTEC: fnum = 256, cost = 0.000, error = 0.00020971
# OLSTEC: fnum = 257, cost = 0.000, error = 0.00021196
# OLSTEC: fnum = 258, cost = 0.000, error = 0.00020202
# OLSTEC: fnum = 259, cost = 0.000, error = 0.00021691
# OLSTEC: fnum = 260, cost = 0.000, error = 0.00021963
# OLSTEC: fnum = 261, cost = 0.000, error = 0.00021021
# OLSTEC: fnum = 262, cost = 0.000, error = 0.00020068
# OLSTEC: fnum = 263, cost = 0.000, error = 0.00022598
# OLSTEC: fnum = 264, cost = 0.000, error = 0.00021015
# OLSTEC: fnum = 265, cost = 0.000, error = 0.00019809
# OLSTEC: fnum = 266, cost = 0.000, error = 0.00019680
# OLSTEC: fnum = 267, cost = 0.000, error = 0.00019766
# OLSTEC: fnum = 268, cost = 0.000, error = 0.00020138
# OLSTEC: fnum = 269, cost = 0.000, error = 0.00020586
# OLSTEC: fnum = 270, cost = 0.000, error = 0.00020336
# OLSTEC: fnum = 271, cost = 0.000, error = 0.00021476
# OLSTEC: fnum = 272, cost = 0.000, error = 0.00022343
# OLSTEC: fnum = 273, cost = 0.000, error = 0.00021135
# OLSTEC: fnum = 274, cost = 0.000, error = 0.00021166
# OLSTEC: fnum = 275, cost = 0.000, error = 0.00020138
# OLSTEC: fnum = 276, cost = 0.000, error = 0.00020605
# OLSTEC: fnum = 277, cost = 0.000, error = 0.00019898
# OLSTEC: fnum = 278, cost = 0.000, error = 0.00021885
# OLSTEC: fnum = 279, cost = 0.000, error = 0.00018363
# OLSTEC: fnum = 280, cost = 0.000, error = 0.00020361
# OLSTEC: fnum = 281, cost = 0.000, error = 0.00020717
# OLSTEC: fnum = 282, cost = 0.000, error = 0.00021393
# OLSTEC: fnum = 283, cost = 0.000, error = 0.00019614
# OLSTEC: fnum = 284, cost = 0.000, error = 0.00021180
# OLSTEC: fnum = 285, cost = 0.000, error = 0.00022873
# OLSTEC: fnum = 286, cost = 0.000, error = 0.00021447
# OLSTEC: fnum = 287, cost = 0.000, error = 0.00021805
# OLSTEC: fnum = 288, cost = 0.000, error = 0.00020703
# OLSTEC: fnum = 289, cost = 0.000, error = 0.00020990
# OLSTEC: fnum = 290, cost = 0.000, error = 0.00021964
# OLSTEC: fnum = 291, cost = 0.000, error = 0.00021021
# OLSTEC: fnum = 292, cost = 0.000, error = 0.00020014
# OLSTEC: fnum = 293, cost = 0.000, error = 0.00021001
# OLSTEC: fnum = 294, cost = 0.000, error = 0.00020616
# OLSTEC: fnum = 295, cost = 0.000, error = 0.00019983
# OLSTEC: fnum = 296, cost = 0.000, error = 0.00021061
# OLSTEC: fnum = 297, cost = 0.000, error = 0.00022558
# OLSTEC: fnum = 298, cost = 0.000, error = 0.00020720
# OLSTEC: fnum = 299, cost = 0.000, error = 0.00020516
# OLSTEC: fnum = 300, cost = 0.000, error = 0.00020280
# OLSTEC Epoch   2, Cost 0.0000000, Cost(test) 0.0000000
# OLSTEC: fnum = 301, cost = 0.000, error = 0.00021788
# OLSTEC: fnum = 302, cost = 0.000, error = 0.00019649
# OLSTEC: fnum = 303, cost = 0.000, error = 0.00019477
# OLSTEC: fnum = 304, cost = 0.000, error = 0.00020393
# OLSTEC: fnum = 305, cost = 0.000, error = 0.00021327
# OLSTEC: fnum = 306, cost = 0.000, error = 0.00020230
# OLSTEC: fnum = 307, cost = 0.000, error = 0.00020916
# OLSTEC: fnum = 308, cost = 0.000, error = 0.00019937
# OLSTEC: fnum = 309, cost = 0.000, error = 0.00019842
# OLSTEC: fnum = 310, cost = 0.000, error = 0.00020283
# OLSTEC: fnum = 311, cost = 0.000, error = 0.00019668
# OLSTEC: fnum = 312, cost = 0.000, error = 0.00019381
# OLSTEC: fnum = 313, cost = 0.000, error = 0.00020536
# OLSTEC: fnum = 314, cost = 0.000, error = 0.00021325
# OLSTEC: fnum = 315, cost = 0.000, error = 0.00019602
# OLSTEC: fnum = 316, cost = 0.000, error = 0.00021497
# OLSTEC: fnum = 317, cost = 0.000, error = 0.00021094
# OLSTEC: fnum = 318, cost = 0.000, error = 0.00019773
# OLSTEC: fnum = 319, cost = 0.000, error = 0.00018857
# OLSTEC: fnum = 320, cost = 0.000, error = 0.00019670
# OLSTEC: fnum = 321, cost = 0.000, error = 0.00021259
# OLSTEC: fnum = 322, cost = 0.000, error = 0.00021814
# OLSTEC: fnum = 323, cost = 0.000, error = 0.00019323
# OLSTEC: fnum = 324, cost = 0.000, error = 0.00020345
# OLSTEC: fnum = 325, cost = 0.000, error = 0.00020654
# OLSTEC: fnum = 326, cost = 0.000, error = 0.00020877
# OLSTEC: fnum = 327, cost = 0.000, error = 0.00020006
# OLSTEC: fnum = 328, cost = 0.000, error = 0.00021206
# OLSTEC: fnum = 329, cost = 0.000, error = 0.00021168
# OLSTEC: fnum = 330, cost = 0.000, error = 0.00019184
# OLSTEC: fnum = 331, cost = 0.000, error = 0.00022463
# OLSTEC: fnum = 332, cost = 0.000, error = 0.00020125
# OLSTEC: fnum = 333, cost = 0.000, error = 0.00021584
# OLSTEC: fnum = 334, cost = 0.000, error = 0.00020854
# OLSTEC: fnum = 335, cost = 0.000, error = 0.00019732
# OLSTEC: fnum = 336, cost = 0.000, error = 0.00019585
# OLSTEC: fnum = 337, cost = 0.000, error = 0.00021041
# OLSTEC: fnum = 338, cost = 0.000, error = 0.00020014
# OLSTEC: fnum = 339, cost = 0.000, error = 0.00020277
# OLSTEC: fnum = 340, cost = 0.000, error = 0.00019896
# OLSTEC: fnum = 341, cost = 0.000, error = 0.00021333
# OLSTEC: fnum = 342, cost = 0.000, error = 0.00020621
# OLSTEC: fnum = 343, cost = 0.000, error = 0.00020919
# OLSTEC: fnum = 344, cost = 0.000, error = 0.00020442
# OLSTEC: fnum = 345, cost = 0.000, error = 0.00022111
# OLSTEC: fnum = 346, cost = 0.000, error = 0.00020381
# OLSTEC: fnum = 347, cost = 0.000, error = 0.00020506
# OLSTEC: fnum = 348, cost = 0.000, error = 0.00019577
# OLSTEC: fnum = 349, cost = 0.000, error = 0.00020493
# OLSTEC: fnum = 350, cost = 0.000, error = 0.00019531
# OLSTEC: fnum = 351, cost = 0.000, error = 0.00020399
# OLSTEC: fnum = 352, cost = 0.000, error = 0.00019978
# OLSTEC: fnum = 353, cost = 0.000, error = 0.00021433
# OLSTEC: fnum = 354, cost = 0.000, error = 0.00020715
# OLSTEC: fnum = 355, cost = 0.000, error = 0.00020220
# OLSTEC: fnum = 356, cost = 0.000, error = 0.00021035
# OLSTEC: fnum = 357, cost = 0.000, error = 0.00021331
# OLSTEC: fnum = 358, cost = 0.000, error = 0.00020213
# OLSTEC: fnum = 359, cost = 0.000, error = 0.00021724
# OLSTEC: fnum = 360, cost = 0.000, error = 0.00022084
# OLSTEC: fnum = 361, cost = 0.000, error = 0.00021051
# OLSTEC: fnum = 362, cost = 0.000, error = 0.00020151
# OLSTEC: fnum = 363, cost = 0.000, error = 0.00022620
# OLSTEC: fnum = 364, cost = 0.000, error = 0.00021078
# OLSTEC: fnum = 365, cost = 0.000, error = 0.00019984
# OLSTEC: fnum = 366, cost = 0.000, error = 0.00019845
# OLSTEC: fnum = 367, cost = 0.000, error = 0.00019812
# OLSTEC: fnum = 368, cost = 0.000, error = 0.00020182
# OLSTEC: fnum = 369, cost = 0.000, error = 0.00020584
# OLSTEC: fnum = 370, cost = 0.000, error = 0.00020332
# OLSTEC: fnum = 371, cost = 0.000, error = 0.00021529
# OLSTEC: fnum = 372, cost = 0.000, error = 0.00022428
# OLSTEC: fnum = 373, cost = 0.000, error = 0.00021135
# OLSTEC: fnum = 374, cost = 0.000, error = 0.00021384
# OLSTEC: fnum = 375, cost = 0.000, error = 0.00020172
# OLSTEC: fnum = 376, cost = 0.000, error = 0.00020601
# OLSTEC: fnum = 377, cost = 0.000, error = 0.00019923
# OLSTEC: fnum = 378, cost = 0.000, error = 0.00021931
# OLSTEC: fnum = 379, cost = 0.000, error = 0.00018542
# OLSTEC: fnum = 380, cost = 0.000, error = 0.00020405
# OLSTEC: fnum = 381, cost = 0.000, error = 0.00020839
# OLSTEC: fnum = 382, cost = 0.000, error = 0.00021507
# OLSTEC: fnum = 383, cost = 0.000, error = 0.00019624
# OLSTEC: fnum = 384, cost = 0.000, error = 0.00021185
# OLSTEC: fnum = 385, cost = 0.000, error = 0.00022880
# OLSTEC: fnum = 386, cost = 0.000, error = 0.00021560
# OLSTEC: fnum = 387, cost = 0.000, error = 0.00021820
# OLSTEC: fnum = 388, cost = 0.000, error = 0.00020710
# OLSTEC: fnum = 389, cost = 0.000, error = 0.00021024
# OLSTEC: fnum = 390, cost = 0.000, error = 0.00022005
# OLSTEC: fnum = 391, cost = 0.000, error = 0.00021120
# OLSTEC: fnum = 392, cost = 0.000, error = 0.00020040
# OLSTEC: fnum = 393, cost = 0.000, error = 0.00021004
# OLSTEC: fnum = 394, cost = 0.000, error = 0.00020617
# OLSTEC: fnum = 395, cost = 0.000, error = 0.00020281
# OLSTEC: fnum = 396, cost = 0.000, error = 0.00021064
# OLSTEC: fnum = 397, cost = 0.000, error = 0.00022592
# OLSTEC: fnum = 398, cost = 0.000, error = 0.00020717
# OLSTEC: fnum = 399, cost = 0.000, error = 0.00020516
# OLSTEC: fnum = 400, cost = 0.000, error = 0.00020299
# OLSTEC Epoch   3, Cost 0.0000000, Cost(test) 0.0000000
# OLSTEC: fnum = 401, cost = 0.000, error = 0.00021822
# OLSTEC: fnum = 402, cost = 0.000, error = 0.00019661
# OLSTEC: fnum = 403, cost = 0.000, error = 0.00019569
# OLSTEC: fnum = 404, cost = 0.000, error = 0.00020409
# OLSTEC: fnum = 405, cost = 0.000, error = 0.00021342
# OLSTEC: fnum = 406, cost = 0.000, error = 0.00020280
# OLSTEC: fnum = 407, cost = 0.000, error = 0.00020911
# OLSTEC: fnum = 408, cost = 0.000, error = 0.00020016
# OLSTEC: fnum = 409, cost = 0.000, error = 0.00019841
# OLSTEC: fnum = 410, cost = 0.000, error = 0.00020368
# OLSTEC: fnum = 411, cost = 0.000, error = 0.00019685
# OLSTEC: fnum = 412, cost = 0.000, error = 0.00019499
# OLSTEC: fnum = 413, cost = 0.000, error = 0.00020530
# OLSTEC: fnum = 414, cost = 0.000, error = 0.00021542
# OLSTEC: fnum = 415, cost = 0.000, error = 0.00019607
# OLSTEC: fnum = 416, cost = 0.000, error = 0.00021550
# OLSTEC: fnum = 417, cost = 0.000, error = 0.00021108
# OLSTEC: fnum = 418, cost = 0.000, error = 0.00019794
# OLSTEC: fnum = 419, cost = 0.000, error = 0.00018872
# OLSTEC: fnum = 420, cost = 0.000, error = 0.00019683
# OLSTEC: fnum = 421, cost = 0.000, error = 0.00021290
# OLSTEC: fnum = 422, cost = 0.000, error = 0.00021808
# OLSTEC: fnum = 423, cost = 0.000, error = 0.00019339
# OLSTEC: fnum = 424, cost = 0.000, error = 0.00020364
# OLSTEC: fnum = 425, cost = 0.000, error = 0.00020666
# OLSTEC: fnum = 426, cost = 0.000, error = 0.00020898
# OLSTEC: fnum = 427, cost = 0.000, error = 0.00020003
# OLSTEC: fnum = 428, cost = 0.000, error = 0.00021323
# OLSTEC: fnum = 429, cost = 0.000, error = 0.00021301
# OLSTEC: fnum = 430, cost = 0.000, error = 0.00019180
# OLSTEC: fnum = 431, cost = 0.000, error = 0.00022482
# OLSTEC: fnum = 432, cost = 0.000, error = 0.00020124
# OLSTEC: fnum = 433, cost = 0.000, error = 0.00021741
# OLSTEC: fnum = 434, cost = 0.000, error = 0.00020871
# OLSTEC: fnum = 435, cost = 0.000, error = 0.00019862
# OLSTEC: fnum = 436, cost = 0.000, error = 0.00019679
# OLSTEC: fnum = 437, cost = 0.000, error = 0.00021049
# OLSTEC: fnum = 438, cost = 0.000, error = 0.00020074
# OLSTEC: fnum = 439, cost = 0.000, error = 0.00020311
# OLSTEC: fnum = 440, cost = 0.000, error = 0.00019919
# OLSTEC: fnum = 441, cost = 0.000, error = 0.00021353
# OLSTEC: fnum = 442, cost = 0.000, error = 0.00020633
# OLSTEC: fnum = 443, cost = 0.000, error = 0.00021087
# OLSTEC: fnum = 444, cost = 0.000, error = 0.00020486
# OLSTEC: fnum = 445, cost = 0.000, error = 0.00022105
# OLSTEC: fnum = 446, cost = 0.000, error = 0.00020398
# OLSTEC: fnum = 447, cost = 0.000, error = 0.00020539
# OLSTEC: fnum = 448, cost = 0.000, error = 0.00019739
# OLSTEC: fnum = 449, cost = 0.000, error = 0.00020499
# OLSTEC: fnum = 450, cost = 0.000, error = 0.00019552
# OLSTEC: fnum = 451, cost = 0.000, error = 0.00020398
# OLSTEC: fnum = 452, cost = 0.000, error = 0.00020000
# OLSTEC: fnum = 453, cost = 0.000, error = 0.00021435
# OLSTEC: fnum = 454, cost = 0.000, error = 0.00020772
# OLSTEC: fnum = 455, cost = 0.000, error = 0.00020254
# OLSTEC: fnum = 456, cost = 0.000, error = 0.00021069
# OLSTEC: fnum = 457, cost = 0.000, error = 0.00021405
# OLSTEC: fnum = 458, cost = 0.000, error = 0.00020218
# OLSTEC: fnum = 459, cost = 0.000, error = 0.00021742
# OLSTEC: fnum = 460, cost = 0.000, error = 0.00022151
# OLSTEC: fnum = 461, cost = 0.000, error = 0.00021066
# OLSTEC: fnum = 462, cost = 0.000, error = 0.00020198
# OLSTEC: fnum = 463, cost = 0.000, error = 0.00022632
# OLSTEC: fnum = 464, cost = 0.000, error = 0.00021114
# OLSTEC: fnum = 465, cost = 0.000, error = 0.00020083
# OLSTEC: fnum = 466, cost = 0.000, error = 0.00019941
# OLSTEC: fnum = 467, cost = 0.000, error = 0.00019838
# OLSTEC: fnum = 468, cost = 0.000, error = 0.00020206
# OLSTEC: fnum = 469, cost = 0.000, error = 0.00020582
# OLSTEC: fnum = 470, cost = 0.000, error = 0.00020329
# OLSTEC: fnum = 471, cost = 0.000, error = 0.00021559
# OLSTEC: fnum = 472, cost = 0.000, error = 0.00022476
# OLSTEC: fnum = 473, cost = 0.000, error = 0.00021134
# OLSTEC: fnum = 474, cost = 0.000, error = 0.00021510
# OLSTEC: fnum = 475, cost = 0.000, error = 0.00020191
# OLSTEC: fnum = 476, cost = 0.000, error = 0.00020597
# OLSTEC: fnum = 477, cost = 0.000, error = 0.00019937
# OLSTEC: fnum = 478, cost = 0.000, error = 0.00021957
# OLSTEC: fnum = 479, cost = 0.000, error = 0.00018647
# OLSTEC: fnum = 480, cost = 0.000, error = 0.00020429
# OLSTEC: fnum = 481, cost = 0.000, error = 0.00020911
# OLSTEC: fnum = 482, cost = 0.000, error = 0.00021572
# OLSTEC: fnum = 483, cost = 0.000, error = 0.00019630
# OLSTEC: fnum = 484, cost = 0.000, error = 0.00021187
# OLSTEC: fnum = 485, cost = 0.000, error = 0.00022882
# OLSTEC: fnum = 486, cost = 0.000, error = 0.00021625
# OLSTEC: fnum = 487, cost = 0.000, error = 0.00021828
# OLSTEC: fnum = 488, cost = 0.000, error = 0.00020713
# OLSTEC: fnum = 489, cost = 0.000, error = 0.00021044
# OLSTEC: fnum = 490, cost = 0.000, error = 0.00022029
# OLSTEC: fnum = 491, cost = 0.000, error = 0.00021178
# OLSTEC: fnum = 492, cost = 0.000, error = 0.00020055
# OLSTEC: fnum = 493, cost = 0.000, error = 0.00021006
# OLSTEC: fnum = 494, cost = 0.000, error = 0.00020616
# OLSTEC: fnum = 495, cost = 0.000, error = 0.00020458
# OLSTEC: fnum = 496, cost = 0.000, error = 0.00021066
# OLSTEC: fnum = 497, cost = 0.000, error = 0.00022612
# OLSTEC: fnum = 498, cost = 0.000, error = 0.00020714
# OLSTEC: fnum = 499, cost = 0.000, error = 0.00020516
# OLSTEC: fnum = 500, cost = 0.000, error = 0.00020310
# OLSTEC Epoch   4, Cost 0.0000000, Cost(test) 0.0000000

# %%
### STC

## Sequential Tensor Completion
from stc import *
Tensor_Y = Tensor_Y_Noiseless.copy()
Mask_Y = OmegaTensor.copy()
numcycles = 1
outer = 7
r1 = r
r2 = r
r3 = r

fun = lambda X, k: [0,np.sqrt(np.sum((X - L_cp)**2)) / L_cp_frob]

Lhat_stc, stats_stc, tElapsed_stc = stc(Tensor_Y,Mask_Y,r1,r2,r3,outer,numcycles,tol=tol,fun=fun,verbose=True)

# nrmse_stc = frobnorm_array(Lhat_stc - L_cp) / L_cp_frob
print('STC Time: {:4f}'.format(tElapsed_stc))
# print('NRMSE STC: {:6f}'.format(nrmse_stc))
# Out:
# Outer[0], Inner[0]: NRMSE: 0.99674277
# Outer[0], Inner[10]: NRMSE: 0.95387870
# Outer[0], Inner[20]: NRMSE: 0.90419928
# Outer[0], Inner[30]: NRMSE: 0.86522471
# Outer[0], Inner[40]: NRMSE: 0.78618740
# Outer[0], Inner[50]: NRMSE: 0.70874621
# Outer[0], Inner[60]: NRMSE: 0.62588150
# Outer[0], Inner[70]: NRMSE: 0.52712183
# Outer[0], Inner[80]: NRMSE: 0.38722915
# Outer[0], Inner[90]: NRMSE: 0.27151501
# Outer[1], Inner[0]: NRMSE: 0.06132658
# Outer[1], Inner[10]: NRMSE: 0.02809218
# Outer[1], Inner[20]: NRMSE: 0.00361681
# Outer[1], Inner[30]: NRMSE: 0.00119665
# Outer[1], Inner[40]: NRMSE: 0.00036382
# Outer[1], Inner[50]: NRMSE: 0.00008035
# Outer[1], Inner[60]: NRMSE: 0.00000814
# Outer[1], Inner[70]: NRMSE: 0.00000305
# Outer[1], Inner[80]: NRMSE: 0.00000097
# Outer[1], Inner[90]: NRMSE: 0.00000005
# Outer[2], Inner[0]: NRMSE: 0.00000002
# Outer[2], Inner[10]: NRMSE: 0.00000001
# Outer[2], Inner[20]: NRMSE: 0.00000000
# STC Time: 4.642442

# %%
nrmse_stc = stats_stc[:,1]
idx = np.where(nrmse_stc > 0)
nrmse_stc = nrmse_stc[idx]
times_stc = stats_stc[:,-1][idx]

# %%
### TOUCAN
tol = 1e-9

fun = lambda X,k: [0,tfrobnorm(X - L) / Lfrob]
L = Tensor(np.transpose(L_cp,(0,2,1)))
Lfrob = tfrobnorm(L)
mask_t = np.transpose(mask,(0,2,1)) 
Y = Tensor(L.array() * mask_t)
# fun = lambda X,k: [0, tfrobnorm_array(X - L.array()[:,k,:]) / tfrobnorm_array(L.array()[:,k,:])]
Y_hat_toucan, U, stats_toucan, tElapsed_toucan = toucan(Y,mask_t,rank=r,tube=tube,outer=3,mode="online",tol=tol,cgiter = None,cgtol=tol,fun=fun,
                                                     randomOrder=False,verbose=True)

toucan_nrmse = tfrobnorm(Y_hat_toucan - L) / Lfrob
print('TOUCAN Time: {:4f}'.format(tElapsed_toucan))
print('TOUCAN NRMSE: {:8f}'.format(toucan_nrmse))

nrmse_toucan = stats_toucan[:,1]
cgiter_toucan = stats_toucan[:,2]
times_toucan = stats_toucan[:,-1]
# Out:
# Outer[0], Inner[0]: NRMSE: 0.99914660
# Outer[0], Inner[10]: NRMSE: 0.96417748
# Outer[0], Inner[20]: NRMSE: 0.91926724
# Outer[0], Inner[30]: NRMSE: 0.88133790
# Outer[0], Inner[40]: NRMSE: 0.80403879
# Outer[0], Inner[50]: NRMSE: 0.72853590
# Outer[0], Inner[60]: NRMSE: 0.64821192
# Outer[0], Inner[70]: NRMSE: 0.55345491
# Outer[0], Inner[80]: NRMSE: 0.42237626
# Outer[0], Inner[90]: NRMSE: 0.31964938
# Outer[1], Inner[0]: NRMSE: 0.16558536
# Outer[1], Inner[10]: NRMSE: 0.09742103
# Outer[1], Inner[20]: NRMSE: 0.03150375
# Outer[1], Inner[30]: NRMSE: 0.01772191
# Outer[1], Inner[40]: NRMSE: 0.00822883
# Outer[1], Inner[50]: NRMSE: 0.00345857
# Outer[1], Inner[60]: NRMSE: 0.00206856
# Outer[1], Inner[70]: NRMSE: 0.00064310
# Outer[1], Inner[80]: NRMSE: 0.00019076
# Outer[1], Inner[90]: NRMSE: 0.00004869
# Outer[2], Inner[0]: NRMSE: 0.00002177
# Outer[2], Inner[10]: NRMSE: 0.00001101
# Outer[2], Inner[20]: NRMSE: 0.00000293
# Outer[2], Inner[30]: NRMSE: 0.00000165
# Outer[2], Inner[40]: NRMSE: 0.00000076
# Outer[2], Inner[50]: NRMSE: 0.00000034
# Outer[2], Inner[60]: NRMSE: 0.00000021
# Outer[2], Inner[70]: NRMSE: 0.00000007
# Outer[2], Inner[80]: NRMSE: 0.00000002
# Outer[2], Inner[90]: NRMSE: 0.00000001
# TOUCAN Time: 8.155934
# TOUCAN NRMSE: 0.000000

# %%
### TNN-ADMM

fun = lambda X: [0, tfrobnorm(X - L) / Lfrob]
niter = 150
Xhat, stats, tElapsed_tensor = lrtc(Y, mask_t, niter=niter,tol=tol, fun=fun, verbose = True)

cost_tnn = stats[:,0]
nrmse_tnn = stats[:,1]
times_tnn = stats[:,2]

print('Time elapsed: Tensor: {:.3f} '.format(tElapsed_tensor))
print('Final NRMSE: Tensor: {:.8f} '.format(nrmse_tnn[-1]))

plt.subplot(1,2,1)
plt.semilogy(cost_tnn)
plt.xlabel('Iteration')
plt.title('Cost function')
plt.subplot(1,2,2)
plt.semilogy(nrmse_tnn)
plt.xlabel('Iteration')
plt.title('NRMSE')
plt.show()
# Out:
# Iter[0]: Cost fxn: 0.000, NRMSE: 1.000000
# Iter[10]: Cost fxn: 0.000, NRMSE: 0.636082
# Iter[20]: Cost fxn: 0.000, NRMSE: 0.086012
# Iter[30]: Cost fxn: 0.000, NRMSE: 0.013496
# Iter[40]: Cost fxn: 0.000, NRMSE: 0.000963
# Iter[50]: Cost fxn: 0.000, NRMSE: 0.000033
# Iter[60]: Cost fxn: 0.000, NRMSE: 0.000002
# Iter[70]: Cost fxn: 0.000, NRMSE: 0.000000
# Time elapsed: Tensor: 16.998
# Final NRMSE: Tensor: 0.00000018

# %%
### TCTF

fun = lambda U,V: [0, tfrobnorm(U*V - L) / Lfrob]
Xtctf,Ztctf, stats_tctf, tElapsed_tctf = tctf(Y,mask_t,rank=r,niter = 200,tol=tol,fun=fun,verbose=True)
Y_hat_tctf = Xtctf * Ztctf

nrmse_tctf = stats_tctf[:,1]
times_tctf = stats_tctf[:,-1]
print('TCTF Time: {:4f}'.format(tElapsed_tctf))
print('TCTF NRMSE: {:8f}'.format(nrmse_tctf[-1]))

plt.semilogy(nrmse_tctf)
plt.xlabel('Iteration')
plt.title('NRMSE')
plt.show()
# Out:
# Iter[1]: NRMSE: 0.312358
# Iter[11]: NRMSE: 0.011112
# Iter[21]: NRMSE: 0.000955
# Iter[31]: NRMSE: 0.000109
# Iter[41]: NRMSE: 0.000014
# Iter[51]: NRMSE: 0.000002
# Iter[61]: NRMSE: 0.000000
# Iter[71]: NRMSE: 0.000000
# Iter[81]: NRMSE: 0.000000
# Iter[91]: NRMSE: 0.000000
# TCTF Time: 6.837990
# TCTF NRMSE: 0.000000

# %%
# L_m = lr_flatten(L_cp)
L_m = np.reshape(L_cp,(n1*n2,n3))
# mask_m = lr_flatten(mask)
mask_m = np.reshape(mask,(n1*n2,n3))

Y_m = L_m * mask_m

# %%
## Matrix Completion

cost_fun = lambda X: [0, np.linalg.norm(X - L_m, 'fro') / np.linalg.norm(L_m, 'fro')]

niter_mc = 200
Xhat_m, stats, tElapsed_matrix = lrmc(Y_m,mask_m,niter=niter_mc,fun=cost_fun)

cost_matrix = stats[:,0]
nrmse_matrix = stats[:,1]
times_matrix = stats[:,2]

print('Time elapsed: Mat Comp: {:.3f} '.format(tElapsed_matrix))
print('Final NRMSE: Mat Comp: {:.8f} '.format(nrmse_matrix[-1]))
# Out:
# Time elapsed: Mat Comp: 5.819
# Final NRMSE: Mat Comp: 0.00000001

# %%
## GROUSE

rank = r
fun = lambda X: [0, np.linalg.norm(X - L_m, 'fro') / np.linalg.norm(L_m, 'fro')]
Ym_hat_grouse, stats_grouse, tElapsed_grouse = grouse(Y_m, mask_m, rank,outer=20,mode="batch",fun=fun,randomOrder=False,
                                                      verbose=False)
grouse_nrmse = np.linalg.norm(Ym_hat_grouse - L_m,'fro') / np.linalg.norm(L_m,'fro')
print('GROUSE Time: {:4f}'.format(tElapsed_grouse))
print('GROUSE NRMSE: {:4f}'.format(grouse_nrmse))
        
nrmse_grouse = stats_grouse[:,1]
times_grouse = stats_grouse[:,-1]
tElapsed_grouse = np.sum(times_grouse)
plt.semilogy(nrmse_grouse)
plt.title('GROUSE: Recovered Tensor NRMSE')
plt.xlabel('Iteration')
plt.show()
# Out:
# GROUSE Time: 0.160721
# GROUSE NRMSE: 0.000000

# %%
plt.figure(figsize=(13,5),tight_layout=True)
plt.semilogy(np.cumsum(times_toucan),nrmse_toucan,'#ff7f0e',label='TOUCAN')
plt.semilogy(np.cumsum(times_tecpsgd),nrmse_tecpsgd,'#00FFFF',label='TeCPSGD')
plt.semilogy(np.cumsum(times_olstec),nrmse_olstec,'#8B008B',label='OLSTEC')
plt.semilogy(np.cumsum(times_tnn),nrmse_tnn,'r',label='TNN-ADMM')
plt.semilogy(np.cumsum(times_tctf),nrmse_tctf,'k',label='TCTF')
plt.semilogy(np.cumsum(times_stc),nrmse_stc,'#FF007F',label='STC')
plt.semilogy(np.cumsum(times_matrix),nrmse_matrix,'g',label='MatComp')
plt.semilogy(np.cumsum(times_grouse),nrmse_grouse,'b',label='GROUSE')
plt.xlabel('Time (s)')
plt.ylabel('NRMSE')
plt.legend(bbox_to_anchor=(1.5,0.5),loc='center right')
plt.rcParams.update({'font.size': 22})
name = 'cp_synth_' + np.str(r) + '-' + np.str(n1) + '-' + np.str(n2) + '-' + np.str(n3) + '_' + np.str(rho * 100) + '.png'
plt.savefig(name)
plt.show()
